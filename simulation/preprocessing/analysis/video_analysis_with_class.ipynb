# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
from video_class import VideoAnalyzer

# %%
# Initialize VideoAnalyzer and use the provided methods
analyzer = VideoAnalyzer(base_path='../../mocap_EMG_EEG_data/data_An_Yu/path1_06', lamp_position=(746, 469))

# %%
# Get total frames in the video
analyzer.get_total_frames()
# Out:
# Total frames in video:  979

# %%
# Find sync marker in the given frame (frame 578)
analyzer.find_sync_marker(frame_number=515)
# Plot sync marker
analyzer.plot_sync_marker()

# %%
# Track brightness of the light throughout the video
analyzer.find_the_light()

# %%
# analyzer.find_green_start_time(green_threshold=126.34)

# %%
# analyzer.plot_green_time(green_time=468)

# %%
# Plot brightness variation over time
analyzer.plot_brightness_over_time()

# %%
# Find start time of the light based on brightness
analyzer.find_start_time()
# Out:
# Highest plateau starts at frame 606 with value 132.1508888888889
# Maximum slope change occurs at frame 611

# %%
# Plot the start time of the light
analyzer.plot_start_time()
